# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %%
N = 1000
X = np.random.random((N,2)) * 6 - 3
y = np.cos(2 *X[:,0]) + np.cos(3*X[:,1])

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],y)

plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128,input_shape=(2,),activation='relu'),
    tf.keras.layers.Dense(1)
])

opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer=opt,loss='mse')
r = model.fit(X,y,epochs=100)
# Out:
# WARNING:tensorflow:From /home/mohsin/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 1000 samples
# Epoch 1/100
# 1000/1000 [==============================] - 0s 275us/sample - loss: 0.9665
# Epoch 2/100
# 1000/1000 [==============================] - 0s 54us/sample - loss: 0.8916
# Epoch 3/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.8835
# Epoch 4/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.8852
# Epoch 5/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.8076
# Epoch 6/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.7479
# Epoch 7/100
# 1000/1000 [==============================] - 0s 65us/sample - loss: 0.6793
# Epoch 8/100
# 1000/1000 [==============================] - 0s 69us/sample - loss: 0.6422
# Epoch 9/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.6422
# Epoch 10/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.5998
# Epoch 11/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.5365
# Epoch 12/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.5117
# Epoch 13/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.5307
# Epoch 14/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4939
# Epoch 15/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.5067
# Epoch 16/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.5233
# Epoch 17/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.4837
# Epoch 18/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.5097
# Epoch 19/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.4792
# Epoch 20/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.4777
# Epoch 21/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.5018
# Epoch 22/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.4750
# Epoch 23/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.4977
# Epoch 24/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.4554
# Epoch 25/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.4704
# Epoch 26/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4452
# Epoch 27/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4857
# Epoch 28/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.4557
# Epoch 29/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.4435
# Epoch 30/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.4391
# Epoch 31/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4163
# Epoch 32/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.4157
# Epoch 33/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.4180
# Epoch 34/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3833
# Epoch 35/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3998
# Epoch 36/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3563
# Epoch 37/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3539
# Epoch 38/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3092
# Epoch 39/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2855
# Epoch 40/100
# 1000/1000 [==============================] - 0s 65us/sample - loss: 0.2730
# Epoch 41/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.2698
# Epoch 42/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3051
# Epoch 43/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.2556
# Epoch 44/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.2314
# Epoch 45/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2151
# Epoch 46/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.1768
# Epoch 47/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.1991
# Epoch 48/100
# 1000/1000 [==============================] - 0s 58us/sample - loss: 0.1508
# Epoch 49/100
# 1000/1000 [==============================] - 0s 56us/sample - loss: 0.1282
# Epoch 50/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.1097
# Epoch 51/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.0943
# Epoch 52/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0880
# Epoch 53/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0826
# Epoch 54/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.0860
# Epoch 55/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.0583
# Epoch 56/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0497
# Epoch 57/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0570
# Epoch 58/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0425
# Epoch 59/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0376
# Epoch 60/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0318
# Epoch 61/100
# 1000/1000 [==============================] - 0s 69us/sample - loss: 0.0337
# Epoch 62/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.0247
# Epoch 63/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0215
# Epoch 64/100
# 1000/1000 [==============================] - 0s 61us/sample - loss: 0.0203
# Epoch 65/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.0172
# Epoch 66/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0237
# Epoch 67/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0177
# Epoch 68/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0181
# Epoch 69/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0207
# Epoch 70/100
# 1000/1000 [==============================] - 0s 70us/sample - loss: 0.0149
# Epoch 71/100
# 1000/1000 [==============================] - 0s 60us/sample - loss: 0.0206
# Epoch 72/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0142
# Epoch 73/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.0151
# Epoch 74/100
# 1000/1000 [==============================] - 0s 52us/sample - loss: 0.0213
# Epoch 75/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.0147
# Epoch 76/100
# 1000/1000 [==============================] - 0s 52us/sample - loss: 0.0112
# Epoch 77/100
# 1000/1000 [==============================] - 0s 73us/sample - loss: 0.0177
# Epoch 78/100
# 1000/1000 [==============================] - 0s 89us/sample - loss: 0.0272
# Epoch 79/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.0224
# Epoch 80/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0116
# Epoch 81/100
# 1000/1000 [==============================] - 0s 52us/sample - loss: 0.0171
# Epoch 82/100
# 1000/1000 [==============================] - 0s 59us/sample - loss: 0.0137
# Epoch 83/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.0114
# Epoch 84/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0106
# Epoch 85/100
# 1000/1000 [==============================] - 0s 60us/sample - loss: 0.0190
# Epoch 86/100
# 1000/1000 [==============================] - 0s 61us/sample - loss: 0.0166
# Epoch 87/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.0149
# Epoch 88/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0173
# Epoch 89/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.0301
# Epoch 90/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0291
# Epoch 91/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0129
# Epoch 92/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0125
# Epoch 93/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0147
# Epoch 94/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0185
# Epoch 95/100
# 1000/1000 [==============================] - 0s 61us/sample - loss: 0.0134
# Epoch 96/100
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.0109
# Epoch 97/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.0134
# Epoch 98/100
# 1000/1000 [==============================] - 0s 56us/sample - loss: 0.0230
# Epoch 99/100
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0148
# Epoch 100/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0106

# %%
plt.plot(r.history['loss'],label='loss')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],y)

line = np.linspace(-3,3,50)
xx,yy = np.meshgrid(line,line)
Xgrid = np.vstack((xx.flatten(),yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0],Xgrid[:,1],Yhat,linewidth=0.2,antialiased=True)
plt.show()

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],y)

line = np.linspace(-5,5,50)
xx,yy = np.meshgrid(line,line)
Xgrid = np.vstack((xx.flatten(),yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0],Xgrid[:,1],Yhat,linewidth=0.2,antialiased=True)
plt.show()
